# %%
import google.generativeai as genai
genai.configure(api_key="AIzaSyBLaqiVjL7WMRL68GEDHCst1wIGenP3Ztg")
model = genai.GenerativeModel("gemini-2.0-flash")
def chat():
    print("hello")
    while True:
        user_input = input("you: ")
        if user_input.lower() == "exit":
            print("chatbot: Bye!")
            break
        response = model.generate_content(user_input)
        print("chatbot:", response.text, "\n")
if __name__ == "__main__":
    chat()
# Out:
# hello
# you:  what is ai
# ---------------------------------------------------------------------------
# PermissionDenied                          Traceback (most recent call last)
# Cell In[1], line 14
#      12         print("chatbot:", response.text, "\n")
#      13 if __name__ == "__main__":
# ---> 14     chat()
#
# Cell In[1], line 11, in chat()
#       9     print("chatbot: Bye!")
#      10     break
# ---> 11 response = model.generate_content(user_input)
#      12 print("chatbot:", response.text, "\n")
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\google\generativeai\generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330     else:
# --> 331         response = self._client.generate_content(
#     332             request,
#     333             **request_options,
#     334         )
#     335         return generation_types.GenerateContentResponse.from_response(response)
#     336 except google.api_core.exceptions.InvalidArgument as e:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:835, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     832 self._validate_universe_domain()
#     834 # Send the request.
# --> 835 response = rpc(
#     836     request,
#     837     retry=retry,
#     838     timeout=timeout,
#     839     metadata=metadata,
#     840 )
#     842 # Done; return the response.
#     843 return response
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\google\api_core\retry\retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 target = functools.partial(func, *args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\google\api_core\retry\retry_unary.py:156, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     152 # pylint: disable=broad-except
#     153 # This function explicitly must deal with broad exceptions.
#     154 except Exception as exc:
#     155     # defer to shared logic for handling errors
# --> 156     next_sleep = _retry_error_helper(
#     157         exc,
#     158         deadline,
#     159         sleep_iter,
#     160         error_list,
#     161         predicate,
#     162         on_error,
#     163         exception_factory,
#     164         timeout,
#     165     )
#     166     # if exception not raised, sleep before next attempt
#     167     time.sleep(next_sleep)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\google\api_core\retry\retry_base.py:214, in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     208 if not predicate_fn(exc):
#     209     final_exc, source_exc = exc_factory_fn(
#     210         error_list,
#     211         RetryFailureReason.NON_RETRYABLE_ERROR,
#     212         original_timeout,
#     213     )
# --> 214     raise final_exc from source_exc
#     215 if on_error_fn is not None:
#     216     on_error_fn(exc)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\google\api_core\retry\retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145 while True:
#     146     try:
# --> 147         result = target()
#     148         if inspect.isawaitable(result):
#     149             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\google\api_core\timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     126         remaining_timeout = self._timeout
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\google\api_core\grpc_helpers.py:77, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      75     return callable_(*args, **kwargs)
#      76 except grpc.RpcError as exc:
# ---> 77     raise exceptions.from_grpc_error(exc) from exc
#
# PermissionDenied: 403 Your API key was reported as leaked. Please use another API key.

# %%
import google.generativeai as genai
genai.configure(api_key="AIzaSyBifHiwnuf23ttpDLy3Uur2yBqEyu1HISE")
model = genai.GenerativeModel("gemini-2.0-flash")
def chat():
    print("hello")
    while True:
        user_input = input("you: ")
        if user_input.lower() == "exit":
            print("chatbot: Bye!")
            break
        response = model.generate_content(user_input)
        print("chatbot:", response.text, "\n")
if __name__ == "__main__":
    chat()
# Out:
# hello
# you:  what is ai
# chatbot: AI, or **Artificial Intelligence**, is a broad term encompassing the development of computer systems that can perform tasks that typically require human intelligence. These tasks include things like:
#
# *   **Learning:** Acquiring information and rules for using the information.
# *   **Reasoning:** Using rules to reach conclusions (either definite or probabilistic).
# *   **Problem-solving:** Devising plans to achieve a goal.
# *   **Perception:** Processing sensory input (like images, sound, or text) to understand the world.
# *   **Natural Language Processing (NLP):** Understanding and generating human language.
#
# Here's a breakdown of key aspects and concepts related to AI:
#
# **Different Types of AI:**
#
# *   **Narrow or Weak AI:** Designed to perform a specific task. Most AI systems today fall into this category. Examples include spam filters, recommendation systems, and self-driving cars.  They excel at their defined task but don't have general intelligence.
#
# *   **General or Strong AI (AGI):** A hypothetical type of AI that can understand, learn, and apply knowledge across a wide range of tasks, much like a human.  AGI doesn't currently exist.
#
# *   **Super AI:** An AI that surpasses human intelligence in all aspects, including creativity, problem-solving, and general wisdom. Also hypothetical.
#
# **Key Techniques & Approaches in AI:**
#
# *   **Machine Learning (ML):** A type of AI where systems learn from data without being explicitly programmed.  Common ML techniques include:
#     *   **Supervised Learning:**  Training a model on labeled data (e.g., images with corresponding object labels).
#     *   **Unsupervised Learning:**  Discovering patterns in unlabeled data (e.g., clustering customers into segments).
#     *   **Reinforcement Learning:**  Training an agent to make decisions in an environment to maximize a reward (e.g., training a game-playing AI).
#
# *   **Deep Learning (DL):** A subset of machine learning that uses artificial neural networks with multiple layers (deep neural networks) to analyze data. DL is particularly effective for complex tasks like image recognition, natural language processing, and speech recognition.
#
# *   **Rule-Based Systems:** AI systems based on a set of predefined rules.  These were common in early AI but are less flexible and adaptable than ML-based systems.
#
# *   **Natural Language Processing (NLP):** Enables computers to understand, interpret, and generate human language.
#
# *   **Computer Vision:** Enables computers to "see" and interpret images and videos.
#
# *   **Robotics:**  Combines AI with physical robots to perform tasks in the real world.
#
# **Examples of AI in Use Today:**
#
# *   **Virtual Assistants:** Siri, Alexa, Google Assistant.
# *   **Recommendation Systems:** Netflix, Amazon, Spotify.
# *   **Spam Filters:** Email providers.
# *   **Fraud Detection:** Banks and credit card companies.
# *   **Medical Diagnosis:** Assisting doctors in identifying diseases.
# *   **Self-Driving Cars:** Tesla, Waymo.
# *   **Chatbots:** Customer service on websites.
# *   **Image Recognition:** Face ID on smartphones.
# *   **Voice Recognition:** Dictation software.
# *   **Generative AI:** Creating new content like text, images, and music (e.g., DALL-E, ChatGPT, Midjourney).
#
# **Ethical Considerations:**
#
# As AI becomes more powerful, ethical concerns are becoming increasingly important.  These include:
#
# *   **Bias:** AI systems can perpetuate and amplify biases present in the data they are trained on.
# *   **Job Displacement:**  AI automation may lead to job losses in certain industries.
# *   **Privacy:** AI systems often collect and process large amounts of personal data, raising privacy concerns.
# *   **Misinformation:** AI can be used to create deepfakes and spread misinformation.
# *   **Autonomous Weapons:** The development of weapons systems that can make decisions without human intervention raises serious ethical questions.
# *   **Transparency and Explainability:** It can be difficult to understand how some AI systems arrive at their decisions, making it hard to identify and correct errors or biases.
#
# **In summary, AI is a rapidly evolving field that aims to create intelligent machines.  It's transforming many aspects of our lives, but it also raises important ethical and societal questions that need to be addressed.**
