# %%
print ("welcome to simple quiz chatbot!")
print("answer the question by typing a,b,c or d\n")
score=0
questions = [
    {
        "question": "What is the largest planet in our solar system?",
        "options": ["A) Earth", "B) Jupiter", "C) Saturn", "D) Neptune"],
        "answer": "B"
    },
    {
        "question": "Who painted the Mona Lisa?",
        "options": ["A) Vincent van Gogh", "B) Pablo Picasso", "C) Leonardo da Vinci", "D) Michelangelo"],
        "answer": "C"
    },
    {
        "question": "What is the capital city of Japan?",
        "options": ["A) Osaka", "B) Tokyo", "C) Kyoto", "D) Hiroshima"],
        "answer": "B"
    },
    {
        "question": "Which gas do plants absorb from the atmosphere?",
        "options": ["A) Oxygen", "B) Nitrogen", "C) Carbon Dioxide", "D) Hydrogen"],
        "answer": "C"
    },
    {
        "question": "How many continents are there in the world?",
        "options": ["A) 5", "B) 6", "C) 7", "D) 8"],
        "answer": "C"
    },
    {
        "question": "Who discovered gravity when he saw an apple fall?",
        "options": ["A) Albert Einstein", "B) Isaac Newton", "C) Galileo Galilei", "D) Nikola Tesla"],
        "answer": "B"
    },
    {
        "question": "Which animal is known as the 'King of the Jungle'?",
        "options": ["A) Tiger", "B) Elephant", "C) Lion", "D) Leopard"],
        "answer": "C"
    },
    {
        "question": "What is the boiling point of water at sea level?",
        "options": ["A) 50°C", "B) 75°C", "C) 100°C", "D) 150°C"],
        "answer": "C"
    },
    {
        "question": "Which country is famous for inventing pizza?",
        "options": ["A) France", "B) Italy", "C) Greece", "D) Spain"],
        "answer": "B"
    },
    {
        "question": "How many degrees are in a right angle?",
        "options": ["A) 30°", "B) 60°", "C) 90°", "D) 180°"],
        "answer": "C"
    }
]

score = 0
print("🤖 Welcome to the General Knowledge Quiz!")
print("Type A, B, C, or D to answer.\n")
for q in questions:
    print(q["question"])
    for option in q["options"]:
        print(option)
user_answer = input("Your answer: ").strip().upper()
    if user_answer == q["answer"]:
        print("✅ Correct!\n")
        score += 1
    else:
        print(f"❌ Wrong! The correct answer was {q['answer']}.\n")
print(f"🎉 Quiz completed! Your final score: {score}/{len(questions)}")
# Out:
#   Cell In[1], line 65
#     if user_answer == q["answer"]:
#     ^
# IndentationError: unexpected indent

# %%
print("Welcome to the simple quiz chatbot!")
print("Answer the question by typing A, B, C or D.\n")
score = 0
questions = [
    {
        "question": "What is the largest planet in our solar system?",
        "options": ["A) Earth", "B) Jupiter", "C) Saturn", "D) Neptune"],
        "answer": "B"
    },
    {
        "question": "Who painted the Mona Lisa?",
        "options": ["A) Vincent van Gogh", "B) Pablo Picasso", "C) Leonardo da Vinci", "D) Michelangelo"],
        "answer": "C"
    },
    {
        "question": "What is the capital city of Japan?",
        "options": ["A) Osaka", "B) Tokyo", "C) Kyoto", "D) Hiroshima"],
        "answer": "B"
    },
    {
        "question": "Which gas do plants absorb?",
        "options": ["A) Oxygen", "B) Nitrogen", "C) Carbon Dioxide", "D) Hydrogen"],
        "answer": "C"
    },
    {
        "question": "How many continents are there?",
        "options": ["A) 5", "B) 6", "C) 7", "D) 8"],
        "answer": "C"
    },
    {
        "question": "Who discovered gravity?",
        "options": ["A) Albert Einstein", "B) Isaac Newton", "C) Galileo Galilei", "D) Nikola Tesla"],
        "answer": "B"
    },
    {
        "question": "Which animal is the 'King of the Jungle'?",
        "options": ["A) Tiger", "B) Elephant", "C) Lion", "D) Leopard"],
        "answer": "C"
    },
    {
        "question": "What is the boiling point of water?",
        "options": ["A) 50°C", "B) 75°C", "C) 100°C", "D) 150°C"],
        "answer": "C"
    },
    {
        "question": "Which country invented pizza?",
        "options": ["A) France", "B) Italy", "C) Greece", "D) Spain"],
        "answer": "B"
    },
    {
        "question": "How many degrees are in a right angle?",
        "options": ["A) 30°", "B) 60°", "C) 90°", "D) 180°"],
        "answer": "C"
    }
]
for q in questions:
    print("\n" + q["question"])
    for option in q["options"]:
        print(option)
    user_answer = input("Your answer: ").strip().upper()
    if user_answer == q["answer"]:
        print("✅ Correct!")
        score += 1
    else:
        print("❌ Wrong! The correct answer was", q["answer"])
print(f"\n🎉 Quiz completed! Your final score: {score}/{len(questions)}")
# Out:
# Welcome to the simple quiz chatbot!
# Answer the question by typing A, B, C or D.
#
#
# What is the largest planet in our solar system?
# A) Earth
# B) Jupiter
# C) Saturn
# D) Neptune
# Your answer:  b
# ✅ Correct!
#
# Who painted the Mona Lisa?
# A) Vincent van Gogh
# B) Pablo Picasso
# C) Leonardo da Vinci
# D) Michelangelo
# Your answer:  b
# ❌ Wrong! The correct answer was C
#
# What is the capital city of Japan?
# A) Osaka
# B) Tokyo
# C) Kyoto
# D) Hiroshima
